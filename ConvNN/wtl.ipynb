# %%
# import tflearn
import pickle
import numpy as np
import tensorflow as tf

# from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn import metrics

from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Flatten
from keras.layers.convolutional import Conv1D
from keras.optimizers import Adam
from keras.models import load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping

data_path = "data_target/"

X = np.load(data_path + "X.npy")
Y = np.load(data_path + "Y.npy")
X_test = np.load(data_path + "X_test.npy")
Y_test = np.load(data_path + "Y_test.npy")

X = np.expand_dims(X, axis=2)
X_test = np.expand_dims(X_test, axis=2)

checkpoint_path = 'Checkpoints/data-target-model-wtl.h5'
early_stopper = EarlyStopping(monitor='loss', patience=10, verbose=0, mode='auto')
checkpointer = ModelCheckpoint(filepath=checkpoint_path, verbose=1, save_best_only=True)

model = Sequential()
model.add(Conv1D(10, kernel_size=3, activation='relu',input_shape=(300, 1)))
model.add(Flatten())
model.add(Dropout(0.1))
model.add(Dense(64, activation='sigmoid'))
model.add(Dropout(0.1))
model.add(Dense(len(Y[0]), activation='softmax'))

# Compile the model
model.compile(loss='binary_crossentropy',
              optimizer=Adam(lr=0.001, decay=1e-8),
              metrics=['accuracy'])

# Fit the model
model.fit(X, Y,
          batch_size=32,
          shuffle=True,
          epochs=2000,
          validation_data=(X_test, Y_test),
          callbacks=[checkpointer, early_stopper])

# load best model
model = load_model(checkpoint_path)

predictions = model.predict(X_test)
predictions = [np.argmax(predictions[i]) for i in range(len(predictions))]
predictions = np.array(predictions)
labels = [np.argmax(Y_test[i]) for i in range(len(Y_test))]
labels = np.array(labels)

print (predictions)
print (labels)

print ("Accuracy: " + str(100*metrics.accuracy_score(labels, predictions)))
print ("Precision: " + str(100*metrics.precision_score(labels, predictions, average="weighted")))
print ("Recall: " + str(100*metrics.recall_score(labels, predictions, average="weighted")))
print ("f1_score: " + str(100*metrics.f1_score(labels, predictions, average="weighted")))

print (model.summary())
print (model.evaluate(X_test, Y_test, batch_size=32))
# Out:
# Train on 136 samples, validate on 91 samples
# Epoch 1/2000
# 136/136 [==============================] - 1s 9ms/step - loss: 0.0748 - acc: 0.9863 - val_loss: 0.0741 - val_acc: 0.9863
#
# Epoch 00001: val_loss improved from inf to 0.07414, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 2/2000
# 136/136 [==============================] - 0s 591us/step - loss: 0.0742 - acc: 0.9863 - val_loss: 0.0736 - val_acc: 0.9863
#
# Epoch 00002: val_loss improved from 0.07414 to 0.07363, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 3/2000
# 136/136 [==============================] - 0s 447us/step - loss: 0.0735 - acc: 0.9863 - val_loss: 0.0732 - val_acc: 0.9863
#
# Epoch 00003: val_loss improved from 0.07363 to 0.07318, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 4/2000
# 136/136 [==============================] - 0s 441us/step - loss: 0.0729 - acc: 0.9863 - val_loss: 0.0728 - val_acc: 0.9863
#
# Epoch 00004: val_loss improved from 0.07318 to 0.07279, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 5/2000
# 136/136 [==============================] - 0s 489us/step - loss: 0.0726 - acc: 0.9863 - val_loss: 0.0724 - val_acc: 0.9863
#
# Epoch 00005: val_loss improved from 0.07279 to 0.07243, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 6/2000
# 136/136 [==============================] - 0s 368us/step - loss: 0.0719 - acc: 0.9863 - val_loss: 0.0721 - val_acc: 0.9863
#
# Epoch 00006: val_loss improved from 0.07243 to 0.07214, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 7/2000
# 136/136 [==============================] - 0s 483us/step - loss: 0.0720 - acc: 0.9863 - val_loss: 0.0719 - val_acc: 0.9863
#
# Epoch 00007: val_loss improved from 0.07214 to 0.07190, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 8/2000
# 136/136 [==============================] - 0s 375us/step - loss: 0.0718 - acc: 0.9863 - val_loss: 0.0717 - val_acc: 0.9863
#
# Epoch 00008: val_loss improved from 0.07190 to 0.07171, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 9/2000
# 136/136 [==============================] - 0s 435us/step - loss: 0.0712 - acc: 0.9863 - val_loss: 0.0716 - val_acc: 0.9863
#
# Epoch 00009: val_loss improved from 0.07171 to 0.07159, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 10/2000
# 136/136 [==============================] - 0s 434us/step - loss: 0.0711 - acc: 0.9863 - val_loss: 0.0715 - val_acc: 0.9863
#
# Epoch 00010: val_loss improved from 0.07159 to 0.07151, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 11/2000
# 136/136 [==============================] - 0s 412us/step - loss: 0.0711 - acc: 0.9863 - val_loss: 0.0714 - val_acc: 0.9863
#
# Epoch 00011: val_loss improved from 0.07151 to 0.07139, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 12/2000
# 136/136 [==============================] - 0s 413us/step - loss: 0.0708 - acc: 0.9863 - val_loss: 0.0713 - val_acc: 0.9863
#
# Epoch 00012: val_loss improved from 0.07139 to 0.07128, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 13/2000
# 136/136 [==============================] - 0s 412us/step - loss: 0.0707 - acc: 0.9863 - val_loss: 0.0712 - val_acc: 0.9863
#
# Epoch 00013: val_loss improved from 0.07128 to 0.07117, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 14/2000
# 136/136 [==============================] - 0s 367us/step - loss: 0.0701 - acc: 0.9863 - val_loss: 0.0711 - val_acc: 0.9863
#
# Epoch 00014: val_loss improved from 0.07117 to 0.07106, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 15/2000
# 136/136 [==============================] - 0s 462us/step - loss: 0.0704 - acc: 0.9863 - val_loss: 0.0709 - val_acc: 0.9863
#
# Epoch 00015: val_loss improved from 0.07106 to 0.07094, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 16/2000
# 136/136 [==============================] - 0s 455us/step - loss: 0.0702 - acc: 0.9863 - val_loss: 0.0708 - val_acc: 0.9863
#
# Epoch 00016: val_loss improved from 0.07094 to 0.07084, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 17/2000
# 136/136 [==============================] - 0s 452us/step - loss: 0.0697 - acc: 0.9863 - val_loss: 0.0707 - val_acc: 0.9863
#
# Epoch 00017: val_loss improved from 0.07084 to 0.07071, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 18/2000
# 136/136 [==============================] - 0s 383us/step - loss: 0.0697 - acc: 0.9863 - val_loss: 0.0706 - val_acc: 0.9863
#
# Epoch 00018: val_loss improved from 0.07071 to 0.07058, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 19/2000
# 136/136 [==============================] - 0s 439us/step - loss: 0.0697 - acc: 0.9863 - val_loss: 0.0704 - val_acc: 0.9863
#
# Epoch 00019: val_loss improved from 0.07058 to 0.07045, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 20/2000
# 136/136 [==============================] - 0s 468us/step - loss: 0.0695 - acc: 0.9863 - val_loss: 0.0703 - val_acc: 0.9863
#
# Epoch 00020: val_loss improved from 0.07045 to 0.07031, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 21/2000
# 136/136 [==============================] - 0s 482us/step - loss: 0.0692 - acc: 0.9863 - val_loss: 0.0702 - val_acc: 0.9863
#
# Epoch 00021: val_loss improved from 0.07031 to 0.07020, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 22/2000
# 136/136 [==============================] - 0s 526us/step - loss: 0.0689 - acc: 0.9863 - val_loss: 0.0701 - val_acc: 0.9863
#
# Epoch 00022: val_loss improved from 0.07020 to 0.07006, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 23/2000
# 136/136 [==============================] - 0s 606us/step - loss: 0.0690 - acc: 0.9863 - val_loss: 0.0699 - val_acc: 0.9863
#
# Epoch 00023: val_loss improved from 0.07006 to 0.06993, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 24/2000
# 136/136 [==============================] - 0s 455us/step - loss: 0.0689 - acc: 0.9863 - val_loss: 0.0698 - val_acc: 0.9863
#
# Epoch 00024: val_loss improved from 0.06993 to 0.06979, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 25/2000
# 136/136 [==============================] - 0s 537us/step - loss: 0.0681 - acc: 0.9863 - val_loss: 0.0696 - val_acc: 0.9863
#
# Epoch 00025: val_loss improved from 0.06979 to 0.06963, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 26/2000
# 136/136 [==============================] - 0s 426us/step - loss: 0.0680 - acc: 0.9863 - val_loss: 0.0695 - val_acc: 0.9863
#
# Epoch 00026: val_loss improved from 0.06963 to 0.06947, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 27/2000
# 136/136 [==============================] - 0s 475us/step - loss: 0.0681 - acc: 0.9863 - val_loss: 0.0692 - val_acc: 0.9863
#
# Epoch 00027: val_loss improved from 0.06947 to 0.06924, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 28/2000
# 136/136 [==============================] - 0s 474us/step - loss: 0.0674 - acc: 0.9863 - val_loss: 0.0690 - val_acc: 0.9863
#
# Epoch 00028: val_loss improved from 0.06924 to 0.06904, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 29/2000
# 136/136 [==============================] - 0s 413us/step - loss: 0.0671 - acc: 0.9863 - val_loss: 0.0689 - val_acc: 0.9863
#
# Epoch 00029: val_loss improved from 0.06904 to 0.06887, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 30/2000
# 136/136 [==============================] - 0s 519us/step - loss: 0.0671 - acc: 0.9863 - val_loss: 0.0687 - val_acc: 0.9863
#
# Epoch 00030: val_loss improved from 0.06887 to 0.06870, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 31/2000
# 136/136 [==============================] - 0s 426us/step - loss: 0.0661 - acc: 0.9863 - val_loss: 0.0685 - val_acc: 0.9863
#
# Epoch 00031: val_loss improved from 0.06870 to 0.06848, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 32/2000
# 136/136 [==============================] - 0s 434us/step - loss: 0.0661 - acc: 0.9863 - val_loss: 0.0683 - val_acc: 0.9863
#
# Epoch 00032: val_loss improved from 0.06848 to 0.06829, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 33/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0662 - acc: 0.9863 - val_loss: 0.0681 - val_acc: 0.9863
#
# Epoch 00033: val_loss improved from 0.06829 to 0.06811, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 34/2000
# 136/136 [==============================] - 0s 345us/step - loss: 0.0655 - acc: 0.9863 - val_loss: 0.0679 - val_acc: 0.9863
#
# Epoch 00034: val_loss improved from 0.06811 to 0.06787, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 35/2000
# 136/136 [==============================] - 0s 365us/step - loss: 0.0651 - acc: 0.9863 - val_loss: 0.0676 - val_acc: 0.9863
#
# Epoch 00035: val_loss improved from 0.06787 to 0.06760, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 36/2000
# 136/136 [==============================] - 0s 381us/step - loss: 0.0649 - acc: 0.9863 - val_loss: 0.0674 - val_acc: 0.9863
#
# Epoch 00036: val_loss improved from 0.06760 to 0.06738, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 37/2000
# 136/136 [==============================] - 0s 420us/step - loss: 0.0641 - acc: 0.9863 - val_loss: 0.0672 - val_acc: 0.9863
#
# Epoch 00037: val_loss improved from 0.06738 to 0.06719, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 38/2000
# 136/136 [==============================] - 0s 353us/step - loss: 0.0643 - acc: 0.9863 - val_loss: 0.0668 - val_acc: 0.9863
#
# Epoch 00038: val_loss improved from 0.06719 to 0.06682, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 39/2000
# 136/136 [==============================] - 0s 374us/step - loss: 0.0635 - acc: 0.9863 - val_loss: 0.0665 - val_acc: 0.9863
#
# Epoch 00039: val_loss improved from 0.06682 to 0.06652, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 40/2000
# 136/136 [==============================] - 0s 360us/step - loss: 0.0632 - acc: 0.9863 - val_loss: 0.0663 - val_acc: 0.9863
#
# Epoch 00040: val_loss improved from 0.06652 to 0.06627, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 41/2000
# 136/136 [==============================] - 0s 425us/step - loss: 0.0627 - acc: 0.9863 - val_loss: 0.0661 - val_acc: 0.9863
#
# Epoch 00041: val_loss improved from 0.06627 to 0.06605, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 42/2000
# 136/136 [==============================] - 0s 422us/step - loss: 0.0628 - acc: 0.9863 - val_loss: 0.0657 - val_acc: 0.9863
#
# Epoch 00042: val_loss improved from 0.06605 to 0.06568, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 43/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0624 - acc: 0.9863 - val_loss: 0.0654 - val_acc: 0.9865
#
# Epoch 00043: val_loss improved from 0.06568 to 0.06538, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 44/2000
# 136/136 [==============================] - 0s 404us/step - loss: 0.0619 - acc: 0.9863 - val_loss: 0.0651 - val_acc: 0.9865
#
# Epoch 00044: val_loss improved from 0.06538 to 0.06512, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 45/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0612 - acc: 0.9865 - val_loss: 0.0650 - val_acc: 0.9865
#
# Epoch 00045: val_loss improved from 0.06512 to 0.06505, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 46/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0612 - acc: 0.9864 - val_loss: 0.0648 - val_acc: 0.9865
#
# Epoch 00046: val_loss improved from 0.06505 to 0.06478, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 47/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0609 - acc: 0.9863 - val_loss: 0.0643 - val_acc: 0.9865
#
# Epoch 00047: val_loss improved from 0.06478 to 0.06432, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 48/2000
# 136/136 [==============================] - 0s 397us/step - loss: 0.0602 - acc: 0.9864 - val_loss: 0.0640 - val_acc: 0.9865
#
# Epoch 00048: val_loss improved from 0.06432 to 0.06401, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 49/2000
# 136/136 [==============================] - 0s 431us/step - loss: 0.0600 - acc: 0.9864 - val_loss: 0.0638 - val_acc: 0.9865
#
# Epoch 00049: val_loss improved from 0.06401 to 0.06385, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 50/2000
# 136/136 [==============================] - 0s 470us/step - loss: 0.0592 - acc: 0.9866 - val_loss: 0.0635 - val_acc: 0.9865
#
# Epoch 00050: val_loss improved from 0.06385 to 0.06353, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 51/2000
# 136/136 [==============================] - 0s 382us/step - loss: 0.0587 - acc: 0.9866 - val_loss: 0.0633 - val_acc: 0.9865
#
# Epoch 00051: val_loss improved from 0.06353 to 0.06330, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 52/2000
# 136/136 [==============================] - 0s 397us/step - loss: 0.0582 - acc: 0.9866 - val_loss: 0.0629 - val_acc: 0.9866
#
# Epoch 00052: val_loss improved from 0.06330 to 0.06292, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 53/2000
# 136/136 [==============================] - 0s 405us/step - loss: 0.0574 - acc: 0.9867 - val_loss: 0.0626 - val_acc: 0.9866
#
# Epoch 00053: val_loss improved from 0.06292 to 0.06258, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 54/2000
# 136/136 [==============================] - 0s 448us/step - loss: 0.0576 - acc: 0.9866 - val_loss: 0.0623 - val_acc: 0.9866
#
# Epoch 00054: val_loss improved from 0.06258 to 0.06233, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 55/2000
# 136/136 [==============================] - 0s 412us/step - loss: 0.0569 - acc: 0.9864 - val_loss: 0.0620 - val_acc: 0.9866
#
# Epoch 00055: val_loss improved from 0.06233 to 0.06203, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 56/2000
# 136/136 [==============================] - 0s 434us/step - loss: 0.0563 - acc: 0.9866 - val_loss: 0.0617 - val_acc: 0.9866
#
# Epoch 00056: val_loss improved from 0.06203 to 0.06172, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 57/2000
# 136/136 [==============================] - 0s 412us/step - loss: 0.0560 - acc: 0.9867 - val_loss: 0.0614 - val_acc: 0.9866
#
# Epoch 00057: val_loss improved from 0.06172 to 0.06144, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 58/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0558 - acc: 0.9867 - val_loss: 0.0611 - val_acc: 0.9866
#
# Epoch 00058: val_loss improved from 0.06144 to 0.06112, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 59/2000
# 136/136 [==============================] - 0s 382us/step - loss: 0.0556 - acc: 0.9865 - val_loss: 0.0609 - val_acc: 0.9866
#
# Epoch 00059: val_loss improved from 0.06112 to 0.06088, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 60/2000
# 136/136 [==============================] - 0s 405us/step - loss: 0.0546 - acc: 0.9866 - val_loss: 0.0606 - val_acc: 0.9866
#
# Epoch 00060: val_loss improved from 0.06088 to 0.06061, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 61/2000
# 136/136 [==============================] - 0s 493us/step - loss: 0.0548 - acc: 0.9868 - val_loss: 0.0602 - val_acc: 0.9866
#
# Epoch 00061: val_loss improved from 0.06061 to 0.06024, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 62/2000
# 136/136 [==============================] - 0s 397us/step - loss: 0.0538 - acc: 0.9869 - val_loss: 0.0599 - val_acc: 0.9866
#
# Epoch 00062: val_loss improved from 0.06024 to 0.05991, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 63/2000
# 136/136 [==============================] - 0s 374us/step - loss: 0.0537 - acc: 0.9869 - val_loss: 0.0596 - val_acc: 0.9866
#
# Epoch 00063: val_loss improved from 0.05991 to 0.05963, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 64/2000
# 136/136 [==============================] - 0s 441us/step - loss: 0.0532 - acc: 0.9867 - val_loss: 0.0592 - val_acc: 0.9866
#
# Epoch 00064: val_loss improved from 0.05963 to 0.05922, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 65/2000
# 136/136 [==============================] - 0s 506us/step - loss: 0.0521 - acc: 0.9868 - val_loss: 0.0589 - val_acc: 0.9866
#
# Epoch 00065: val_loss improved from 0.05922 to 0.05889, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 66/2000
# 136/136 [==============================] - 0s 375us/step - loss: 0.0521 - acc: 0.9868 - val_loss: 0.0587 - val_acc: 0.9866
#
# Epoch 00066: val_loss improved from 0.05889 to 0.05874, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 67/2000
# 136/136 [==============================] - 0s 404us/step - loss: 0.0516 - acc: 0.9868 - val_loss: 0.0583 - val_acc: 0.9866
#
# Epoch 00067: val_loss improved from 0.05874 to 0.05828, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 68/2000
# 136/136 [==============================] - 0s 360us/step - loss: 0.0512 - acc: 0.9868 - val_loss: 0.0580 - val_acc: 0.9868
#
# Epoch 00068: val_loss improved from 0.05828 to 0.05803, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 69/2000
# 136/136 [==============================] - 0s 388us/step - loss: 0.0508 - acc: 0.9866 - val_loss: 0.0577 - val_acc: 0.9868
#
# Epoch 00069: val_loss improved from 0.05803 to 0.05769, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 70/2000
# 136/136 [==============================] - 0s 363us/step - loss: 0.0505 - acc: 0.9869 - val_loss: 0.0573 - val_acc: 0.9868
#
# Epoch 00070: val_loss improved from 0.05769 to 0.05734, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 71/2000
# 136/136 [==============================] - 0s 369us/step - loss: 0.0500 - acc: 0.9869 - val_loss: 0.0571 - val_acc: 0.9868
#
# Epoch 00071: val_loss improved from 0.05734 to 0.05715, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 72/2000
# 136/136 [==============================] - 0s 390us/step - loss: 0.0496 - acc: 0.9869 - val_loss: 0.0569 - val_acc: 0.9868
#
# Epoch 00072: val_loss improved from 0.05715 to 0.05687, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 73/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0490 - acc: 0.9871 - val_loss: 0.0566 - val_acc: 0.9869
#
# Epoch 00073: val_loss improved from 0.05687 to 0.05658, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 74/2000
# 136/136 [==============================] - 0s 404us/step - loss: 0.0488 - acc: 0.9870 - val_loss: 0.0563 - val_acc: 0.9868
#
# Epoch 00074: val_loss improved from 0.05658 to 0.05627, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 75/2000
# 136/136 [==============================] - 0s 399us/step - loss: 0.0482 - acc: 0.9869 - val_loss: 0.0558 - val_acc: 0.9869
#
# Epoch 00075: val_loss improved from 0.05627 to 0.05577, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 76/2000
# 136/136 [==============================] - 0s 448us/step - loss: 0.0476 - acc: 0.9870 - val_loss: 0.0556 - val_acc: 0.9868
#
# Epoch 00076: val_loss improved from 0.05577 to 0.05558, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 77/2000
# 136/136 [==============================] - 0s 384us/step - loss: 0.0470 - acc: 0.9872 - val_loss: 0.0552 - val_acc: 0.9868
#
# Epoch 00077: val_loss improved from 0.05558 to 0.05523, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 78/2000
# 136/136 [==============================] - 0s 376us/step - loss: 0.0468 - acc: 0.9873 - val_loss: 0.0550 - val_acc: 0.9869
#
# Epoch 00078: val_loss improved from 0.05523 to 0.05500, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 79/2000
# 136/136 [==============================] - 0s 530us/step - loss: 0.0465 - acc: 0.9872 - val_loss: 0.0545 - val_acc: 0.9869
#
# Epoch 00079: val_loss improved from 0.05500 to 0.05447, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 80/2000
# 136/136 [==============================] - 0s 426us/step - loss: 0.0454 - acc: 0.9872 - val_loss: 0.0541 - val_acc: 0.9869
#
# Epoch 00080: val_loss improved from 0.05447 to 0.05410, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 81/2000
# 136/136 [==============================] - 0s 376us/step - loss: 0.0449 - acc: 0.9872 - val_loss: 0.0538 - val_acc: 0.9869
#
# Epoch 00081: val_loss improved from 0.05410 to 0.05383, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 82/2000
# 136/136 [==============================] - 0s 378us/step - loss: 0.0447 - acc: 0.9873 - val_loss: 0.0535 - val_acc: 0.9868
#
# Epoch 00082: val_loss improved from 0.05383 to 0.05349, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 83/2000
# 136/136 [==============================] - 0s 375us/step - loss: 0.0441 - acc: 0.9873 - val_loss: 0.0531 - val_acc: 0.9869
#
# Epoch 00083: val_loss improved from 0.05349 to 0.05312, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 84/2000
# 136/136 [==============================] - 0s 397us/step - loss: 0.0436 - acc: 0.9873 - val_loss: 0.0527 - val_acc: 0.9869
#
# Epoch 00084: val_loss improved from 0.05312 to 0.05271, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 85/2000
# 136/136 [==============================] - 0s 428us/step - loss: 0.0428 - acc: 0.9874 - val_loss: 0.0524 - val_acc: 0.9869
#
# Epoch 00085: val_loss improved from 0.05271 to 0.05242, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 86/2000
# 136/136 [==============================] - 0s 360us/step - loss: 0.0428 - acc: 0.9872 - val_loss: 0.0522 - val_acc: 0.9868
#
# Epoch 00086: val_loss improved from 0.05242 to 0.05217, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 87/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0423 - acc: 0.9874 - val_loss: 0.0518 - val_acc: 0.9868
#
# Epoch 00087: val_loss improved from 0.05217 to 0.05183, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 88/2000
# 136/136 [==============================] - 0s 375us/step - loss: 0.0419 - acc: 0.9873 - val_loss: 0.0515 - val_acc: 0.9869
#
# Epoch 00088: val_loss improved from 0.05183 to 0.05146, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 89/2000
# 136/136 [==============================] - 0s 397us/step - loss: 0.0417 - acc: 0.9875 - val_loss: 0.0510 - val_acc: 0.9868
#
# Epoch 00089: val_loss improved from 0.05146 to 0.05097, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 90/2000
# 136/136 [==============================] - 0s 397us/step - loss: 0.0410 - acc: 0.9874 - val_loss: 0.0506 - val_acc: 0.9868
#
# Epoch 00090: val_loss improved from 0.05097 to 0.05058, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 91/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0404 - acc: 0.9877 - val_loss: 0.0505 - val_acc: 0.9868
#
# Epoch 00091: val_loss improved from 0.05058 to 0.05050, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 92/2000
# 136/136 [==============================] - 0s 397us/step - loss: 0.0398 - acc: 0.9875 - val_loss: 0.0501 - val_acc: 0.9868
#
# Epoch 00092: val_loss improved from 0.05050 to 0.05009, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 93/2000
# 136/136 [==============================] - 0s 414us/step - loss: 0.0397 - acc: 0.9878 - val_loss: 0.0498 - val_acc: 0.9869
#
# Epoch 00093: val_loss improved from 0.05009 to 0.04983, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 94/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0392 - acc: 0.9876 - val_loss: 0.0496 - val_acc: 0.9871
#
# Epoch 00094: val_loss improved from 0.04983 to 0.04964, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 95/2000
# 136/136 [==============================] - 0s 533us/step - loss: 0.0381 - acc: 0.9880 - val_loss: 0.0493 - val_acc: 0.9868
#
# Epoch 00095: val_loss improved from 0.04964 to 0.04931, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 96/2000
# 136/136 [==============================] - 0s 557us/step - loss: 0.0387 - acc: 0.9878 - val_loss: 0.0488 - val_acc: 0.9869
#
# Epoch 00096: val_loss improved from 0.04931 to 0.04876, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 97/2000
# 136/136 [==============================] - 0s 565us/step - loss: 0.0376 - acc: 0.9878 - val_loss: 0.0485 - val_acc: 0.9871
#
# Epoch 00097: val_loss improved from 0.04876 to 0.04848, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 98/2000
# 136/136 [==============================] - 0s 366us/step - loss: 0.0376 - acc: 0.9878 - val_loss: 0.0483 - val_acc: 0.9869
#
# Epoch 00098: val_loss improved from 0.04848 to 0.04831, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 99/2000
# 136/136 [==============================] - 0s 483us/step - loss: 0.0366 - acc: 0.9881 - val_loss: 0.0479 - val_acc: 0.9869
#
# Epoch 00099: val_loss improved from 0.04831 to 0.04790, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 100/2000
# 136/136 [==============================] - 0s 441us/step - loss: 0.0363 - acc: 0.9881 - val_loss: 0.0476 - val_acc: 0.9869
#
# Epoch 00100: val_loss improved from 0.04790 to 0.04756, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 101/2000
# 136/136 [==============================] - 0s 419us/step - loss: 0.0362 - acc: 0.9883 - val_loss: 0.0472 - val_acc: 0.9869
#
# Epoch 00101: val_loss improved from 0.04756 to 0.04720, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 102/2000
# 136/136 [==============================] - 0s 375us/step - loss: 0.0356 - acc: 0.9883 - val_loss: 0.0469 - val_acc: 0.9869
#
# Epoch 00102: val_loss improved from 0.04720 to 0.04694, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 103/2000
# 136/136 [==============================] - 0s 463us/step - loss: 0.0349 - acc: 0.9880 - val_loss: 0.0466 - val_acc: 0.9869
#
# Epoch 00103: val_loss improved from 0.04694 to 0.04657, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 104/2000
# 136/136 [==============================] - 0s 463us/step - loss: 0.0347 - acc: 0.9881 - val_loss: 0.0463 - val_acc: 0.9869
#
# Epoch 00104: val_loss improved from 0.04657 to 0.04628, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 105/2000
# 136/136 [==============================] - 0s 551us/step - loss: 0.0342 - acc: 0.9884 - val_loss: 0.0459 - val_acc: 0.9869
#
# Epoch 00105: val_loss improved from 0.04628 to 0.04590, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 106/2000
# 136/136 [==============================] - 0s 426us/step - loss: 0.0338 - acc: 0.9886 - val_loss: 0.0458 - val_acc: 0.9869
#
# Epoch 00106: val_loss improved from 0.04590 to 0.04576, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 107/2000
# 136/136 [==============================] - 0s 441us/step - loss: 0.0333 - acc: 0.9886 - val_loss: 0.0453 - val_acc: 0.9869
#
# Epoch 00107: val_loss improved from 0.04576 to 0.04532, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 108/2000
# 136/136 [==============================] - 0s 479us/step - loss: 0.0325 - acc: 0.9889 - val_loss: 0.0454 - val_acc: 0.9869
#
# Epoch 00108: val_loss did not improve from 0.04532
# Epoch 109/2000
# 136/136 [==============================] - 0s 426us/step - loss: 0.0325 - acc: 0.9889 - val_loss: 0.0449 - val_acc: 0.9869
#
# Epoch 00109: val_loss improved from 0.04532 to 0.04489, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 110/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0320 - acc: 0.9887 - val_loss: 0.0445 - val_acc: 0.9871
#
# Epoch 00110: val_loss improved from 0.04489 to 0.04451, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 111/2000
# 136/136 [==============================] - 0s 424us/step - loss: 0.0320 - acc: 0.9892 - val_loss: 0.0440 - val_acc: 0.9871
#
# Epoch 00111: val_loss improved from 0.04451 to 0.04396, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 112/2000
# 136/136 [==============================] - 0s 386us/step - loss: 0.0315 - acc: 0.9895 - val_loss: 0.0438 - val_acc: 0.9871
#
# Epoch 00112: val_loss improved from 0.04396 to 0.04382, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 113/2000
# 136/136 [==============================] - 0s 407us/step - loss: 0.0315 - acc: 0.9891 - val_loss: 0.0436 - val_acc: 0.9872
#
# Epoch 00113: val_loss improved from 0.04382 to 0.04362, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 114/2000
# 136/136 [==============================] - 0s 404us/step - loss: 0.0308 - acc: 0.9894 - val_loss: 0.0435 - val_acc: 0.9874
#
# Epoch 00114: val_loss improved from 0.04362 to 0.04347, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 115/2000
# 136/136 [==============================] - 0s 468us/step - loss: 0.0308 - acc: 0.9897 - val_loss: 0.0430 - val_acc: 0.9877
#
# Epoch 00115: val_loss improved from 0.04347 to 0.04295, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 116/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0296 - acc: 0.9903 - val_loss: 0.0426 - val_acc: 0.9874
#
# Epoch 00116: val_loss improved from 0.04295 to 0.04261, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 117/2000
# 136/136 [==============================] - 0s 367us/step - loss: 0.0297 - acc: 0.9898 - val_loss: 0.0423 - val_acc: 0.9874
#
# Epoch 00117: val_loss improved from 0.04261 to 0.04229, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 118/2000
# 136/136 [==============================] - 0s 448us/step - loss: 0.0289 - acc: 0.9901 - val_loss: 0.0423 - val_acc: 0.9877
#
# Epoch 00118: val_loss did not improve from 0.04229
# Epoch 119/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0287 - acc: 0.9901 - val_loss: 0.0419 - val_acc: 0.9878
#
# Epoch 00119: val_loss improved from 0.04229 to 0.04186, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 120/2000
# 136/136 [==============================] - 0s 405us/step - loss: 0.0282 - acc: 0.9901 - val_loss: 0.0417 - val_acc: 0.9877
#
# Epoch 00120: val_loss improved from 0.04186 to 0.04168, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 121/2000
# 136/136 [==============================] - 0s 395us/step - loss: 0.0281 - acc: 0.9903 - val_loss: 0.0412 - val_acc: 0.9875
#
# Epoch 00121: val_loss improved from 0.04168 to 0.04116, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 122/2000
# 136/136 [==============================] - 0s 412us/step - loss: 0.0277 - acc: 0.9902 - val_loss: 0.0410 - val_acc: 0.9877
#
# Epoch 00122: val_loss improved from 0.04116 to 0.04100, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 123/2000
# 136/136 [==============================] - 0s 404us/step - loss: 0.0271 - acc: 0.9905 - val_loss: 0.0407 - val_acc: 0.9880
#
# Epoch 00123: val_loss improved from 0.04100 to 0.04068, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 124/2000
# 136/136 [==============================] - 0s 450us/step - loss: 0.0269 - acc: 0.9904 - val_loss: 0.0406 - val_acc: 0.9878
#
# Epoch 00124: val_loss improved from 0.04068 to 0.04057, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 125/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0266 - acc: 0.9906 - val_loss: 0.0404 - val_acc: 0.9878
#
# Epoch 00125: val_loss improved from 0.04057 to 0.04036, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 126/2000
# 136/136 [==============================] - 0s 470us/step - loss: 0.0265 - acc: 0.9906 - val_loss: 0.0401 - val_acc: 0.9880
#
# Epoch 00126: val_loss improved from 0.04036 to 0.04007, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 127/2000
# 136/136 [==============================] - 0s 502us/step - loss: 0.0258 - acc: 0.9907 - val_loss: 0.0396 - val_acc: 0.9880
#
# Epoch 00127: val_loss improved from 0.04007 to 0.03962, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 128/2000
# 136/136 [==============================] - 0s 525us/step - loss: 0.0254 - acc: 0.9908 - val_loss: 0.0396 - val_acc: 0.9881
#
# Epoch 00128: val_loss improved from 0.03962 to 0.03955, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 129/2000
# 136/136 [==============================] - 0s 477us/step - loss: 0.0246 - acc: 0.9909 - val_loss: 0.0393 - val_acc: 0.9878
#
# Epoch 00129: val_loss improved from 0.03955 to 0.03935, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 130/2000
# 136/136 [==============================] - 0s 364us/step - loss: 0.0244 - acc: 0.9908 - val_loss: 0.0389 - val_acc: 0.9881
#
# Epoch 00130: val_loss improved from 0.03935 to 0.03891, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 131/2000
# 136/136 [==============================] - 0s 507us/step - loss: 0.0245 - acc: 0.9909 - val_loss: 0.0388 - val_acc: 0.9883
#
# Epoch 00131: val_loss improved from 0.03891 to 0.03875, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 132/2000
# 136/136 [==============================] - 0s 500us/step - loss: 0.0244 - acc: 0.9910 - val_loss: 0.0385 - val_acc: 0.9883
#
# Epoch 00132: val_loss improved from 0.03875 to 0.03851, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 133/2000
# 136/136 [==============================] - 0s 360us/step - loss: 0.0236 - acc: 0.9913 - val_loss: 0.0381 - val_acc: 0.9883
#
# Epoch 00133: val_loss improved from 0.03851 to 0.03811, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 134/2000
# 136/136 [==============================] - 0s 389us/step - loss: 0.0233 - acc: 0.9915 - val_loss: 0.0379 - val_acc: 0.9881
#
# Epoch 00134: val_loss improved from 0.03811 to 0.03794, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 135/2000
# 136/136 [==============================] - 0s 525us/step - loss: 0.0232 - acc: 0.9915 - val_loss: 0.0378 - val_acc: 0.9883
#
# Epoch 00135: val_loss improved from 0.03794 to 0.03777, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 136/2000
# 136/136 [==============================] - 0s 382us/step - loss: 0.0228 - acc: 0.9912 - val_loss: 0.0373 - val_acc: 0.9883
#
# Epoch 00136: val_loss improved from 0.03777 to 0.03733, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 137/2000
# 136/136 [==============================] - 0s 494us/step - loss: 0.0223 - acc: 0.9915 - val_loss: 0.0372 - val_acc: 0.9883
#
# Epoch 00137: val_loss improved from 0.03733 to 0.03717, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 138/2000
# 136/136 [==============================] - 0s 437us/step - loss: 0.0220 - acc: 0.9920 - val_loss: 0.0372 - val_acc: 0.9883
#
# Epoch 00138: val_loss did not improve from 0.03717
# Epoch 139/2000
# 136/136 [==============================] - 0s 358us/step - loss: 0.0220 - acc: 0.9916 - val_loss: 0.0368 - val_acc: 0.9883
#
# Epoch 00139: val_loss improved from 0.03717 to 0.03683, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 140/2000
# 136/136 [==============================] - 0s 388us/step - loss: 0.0211 - acc: 0.9919 - val_loss: 0.0365 - val_acc: 0.9883
#
# Epoch 00140: val_loss improved from 0.03683 to 0.03649, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 141/2000
# 136/136 [==============================] - 0s 381us/step - loss: 0.0210 - acc: 0.9924 - val_loss: 0.0365 - val_acc: 0.9883
#
# Epoch 00141: val_loss improved from 0.03649 to 0.03645, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 142/2000
# 136/136 [==============================] - 0s 404us/step - loss: 0.0209 - acc: 0.9925 - val_loss: 0.0360 - val_acc: 0.9883
#
# Epoch 00142: val_loss improved from 0.03645 to 0.03603, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 143/2000
# 136/136 [==============================] - 0s 331us/step - loss: 0.0202 - acc: 0.9925 - val_loss: 0.0358 - val_acc: 0.9886
#
# Epoch 00143: val_loss improved from 0.03603 to 0.03585, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 144/2000
# 136/136 [==============================] - 0s 325us/step - loss: 0.0202 - acc: 0.9922 - val_loss: 0.0356 - val_acc: 0.9884
#
# Epoch 00144: val_loss improved from 0.03585 to 0.03565, saving model to Checkpoints/data-target-model-wtl.h5
# Epoch 145/2000
# 136/136 [==============================] - 0s 367us/step - loss: 0.0202 - acc: 0.9925 - val_loss: 0.0355 - val_acc: 0.9887
